# %% [markdown]
# # CHATBOT USING LANGCHAIN AND PINECONE

# %%
import os
import openai

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file
openai.api_key = os.environ['OPENAI_API_KEY']
pinecone_api_key = os.environ['PINECONE_API_KEY']

# %% [markdown]
# # Document loader

# %%
#json file path
file_path='dataset_final_with_questions.json'

# %%
from pprint import pprint
import json
# load json file and view the contents
with open(file_path) as file:
    data_set = json.load(file)
pprint(data_set)
# Out:
# [{'source': 'https://www.canada.ca/en/immigration-refugees-citizenship/services/immigrate-canada/express-entry/apply-permanent-residence/check-your-status.html',
#   'subheadings': [{'content': '1. Fill out the online form\n'
#                               '2. Scan and upload the documents\n'
#                               '3. Pay your fees\n'
#                               '4. Submit your complete application\n'
#                               '5. After you apply\n'
#                               'Check your application status',
#                    'questions': ['1. What are the steps involved in the '
#                                  'Express Entry application process?',
#                                  '2. How can I check the status of my Express '
#                                  'Entry application?',
#                                  '3. What is the first step in the Express '
#                                  'Entry application process?',
#                                  '4. What documents do I need to scan and '
#                                  'upload for my Express Entry application?',
#                                  '5. What should I do after submitting my '
#                                  'complete Express Entry application?'],
#                    'subheading': 'Search'},
#                   {'content': 'Starting February 8, 2023, use the application '
#                               'status tracker(opens in a new tab)\xa0 to get '
#                               'the most up-to-date and detailed information '
#                               'about the status of your application.\n'
#                               'You have 60 days after you’ve been invited to '
#                               'apply to submit your application for permanent '
#                               'residence.\n'
#                               'Once you have submitted your application, you '
#                               'can check its status in your account.\n'
#                               'Go to “View the applications you submitted”\n'
#                               'Click “Application status and messages”\n'
#                               'On the “Application status and messages” page, '
#                               'you’re able to see\n'
#                               'the overall status of your application\n'
#                               'the current status of each application step\n'
#                               'messages with additional steps to take, if '
#                               'required\n'
#                               'If you need to make updates to your account, '
#                               'we’ll send you an email. Make sure you complete '
#                               'the requested updates as soon as possible, or '
#                               'the processing of your application could be '
#                               'delayed.',
#                    'questions': ['1. How can I check the status of my Express '
#                                  'Entry application?',
#                                  '2. When can I start checking the status of '
#                                  'my application?',
#                                  '3. What information can I see on the '
#                                  '"Application status and messages" page?',
#                                  '4. What should I do if I receive an email '
#                                  'requesting updates to my account?',
#                                  '5. How long do I have to submit my '
#                                  'application after receiving an invitation to '
#                                  'apply?'],
#                    'subheading': 'Check your application status online'},
#                   {'content': 'We process most Express Entry applications '
#                               'within 6 months or less of getting your '
#                               'complete application.',
#                    'questions': ['1. How long does it typically take to '
#                                  'process Express Entry applications?',
#                                  '2. What is the average processing time for '
#                                  'Express Entry applications?',
#                                  '3. Is it possible for Express Entry '
#                                  'applications to be processed in less than 6 '
#                                  'months?',
#                                  '4. What is the maximum processing time for '
#                                  'Express Entry applications?',
#                                  '5. What is the importance of submitting a '
#                                  'complete application for Express Entry?'],
#                    'subheading': 'Processing times'},
#                   {'content': '\n'
#                               ' Varies by program\n'
#                               '\n'
#                               'You may need to give your biometrics with your '
#                               'application. This processing time includes the '
#                               'time you need to give your biometrics.',
#                    'questions': ['1. How can I check the status of my Express '
#                                  'Entry application?',
#                                  '2. What factors determine the processing '
#                                  'time for an Express Entry application?',
#                                  '3. Is it mandatory to provide biometrics '
#                                  'with an Express Entry application?',
#                                  '4. Does the processing time for an Express '
#                                  'Entry application include the time required '
#                                  'for biometrics?',
#                                  '5. Are there different processing times for '
#                                  'different programs under Express Entry?'],
#                    'subheading': 'Processing time\xa0?'},
#                   {'content': 'Processing times will vary based on:\n'
#                               'the type of application submitted\n'
#                               'if the application is complete\n'
#                               'how quickly we expect to process applications '
#                               'we’ve already received\n'
#                               'how easily we can verify your information\n'
#                               'how long you take to respond to any requests or '
#                               'concerns\n'
#                               'other factors\n'
#                               'More people want to immigrate to Canada than we '
#                               'can bring in each year. Applications received '
#                               'after we meet our yearly limit may have to wait '
#                               'longer to be processed.\n'
#                               'Learn how processing times are calculated.',
#                    'questions': ['1. What factors can affect the processing '
#                                  'time of an Express Entry application?',
#                                  '2. How does the type of application '
#                                  'submitted impact the processing time?',
#                                  '3. What role does the completeness of an '
#                                  'application play in the processing time?',
#                                  '4. How does the yearly limit on immigration '
#                                  'affect the processing time of applications '
#                                  'received after the limit is met?',
#                                  '5. How are processing times calculated for '
#                                  'Express Entry applications?'],
#                    'subheading': 'Processing times'},
#                   {'content': 'Your application will be delayed if\n'
#                               'we need to verify information\n'
#                               'there are criminal or security problems\n'
#                               'we need to do more background checks\n'
#                               "your family situation isn't clear, for "
#                               'example,\r\n'
#                               '        \n'
#                               "a divorce or an adoption that isn't yet "
#                               'complete\n'
#                               "child custody issues that haven't been "
#                               'resolved\n'
#                               '\n'
#                               '\n'
#                               "a divorce or an adoption that isn't yet "
#                               'complete\n'
#                               "child custody issues that haven't been "
#                               'resolved\n'
#                               'you need to submit more documents or have an '
#                               'interview with us',
#                    'questions': ['1. What are some common causes of processing '
#                                  'delays in Express Entry applications?',
#                                  '2. How does the verification of information '
#                                  'contribute to application delays?',
#                                  '3. What types of criminal or security '
#                                  'problems can result in delays?',
#                                  "4. Why might a family situation that isn't "
#                                  'clear cause a delay in the application '
#                                  'process?',
#                                  '5. When might an applicant be required to '
#                                  'submit additional documents or have an '
#                                  'interview?'],
#                    'subheading': 'Causes of processing delays'},
#                   {'content': 'Avoid delays by updating your information. You '
#                               'can use the IRCC web form if you need to report '
#                               'important changes about your application, such '
#                               'as\n'
#                               'changes of mailing or email address, telephone '
#                               'number or other contact information\n'
#                               'births or deaths in your family\n'
#                               'marriages\n'
#                               'divorces\n'
#                               'adoptions\n'
#                               'changes to your job or job offer\n'
#                               'new educational credentials\n'
#                               'updated language test results',
#                    'questions': ['1. How can I check the status of my Express '
#                                  'Entry application?',
#                                  '2. What should I do if there are changes to '
#                                  'my contact information?',
#                                  '3. What types of changes should I report '
#                                  'about my application?',
#                                  '4. How can I update my job or job offer '
#                                  'information?',
#                                  '5. Can I update my language test results '
#                                  'after submitting my application?'],
#                    'subheading': 'Keep your information up to date'}],
#   'title': '\nExpress Entry: Check your application status'},
#  {'source': 'https://www.canada.ca/en/immigration-refugees-citizenship/services/immigrate-canada.html',
#   'subheadings': [{'content': '', 'subheading': 'Language selection'},
#                   {'content': '', 'subheading': 'Search'},
#                   {'content': 'Jobs and the workplace\n'
#                               'Immigration and citizenship\n'
#                               'Travel and tourism\n'
#                               'Business and industry\n'
#                               'Benefits\n'
#                               'Health\n'
#                               'Taxes\n'
#                               'Environment and natural resources\n'
#                               'National security and defence\n'
#                               'Culture, history and sport\n'
#                               'Policing, justice and emergencies\n'
#                               'Transport and infrastructure\n'
#                               'Canada and the world\n'
#                               'Money and finances\n'
#                               'Science and innovation\n'
#                               '\n',
#                    'questions': ['1. What are the job opportunities available '
#                                  'for immigrants in Canada?',
#                                  '2. How can one obtain immigration and '
#                                  'citizenship in Canada?',
#                                  '3. What are the popular travel and tourism '
#                                  'destinations in Canada?',
#                                  '4. What are the key industries and '
#                                  'businesses in Canada?',
#                                  '5. What benefits are available to immigrants '
#                                  'in Canada?'],
#                    'subheading': 'Menu'},
#                   {'content': '', 'subheading': 'You are here:'},
#                   {'content': 'Prepare for life in Canada\n'
#                               'Create an account or sign in\n'
#                               'Use a representative\n'
#                               '\n',
#                    'questions': ['1. How can I prepare for life in Canada?',
#                                  '2. What are the steps to create an account '
#                                  'or sign in?',
#                                  '3. Why should I consider using a '
#                                  'representative for immigration to Canada?',
#                                  '4. What are the benefits of immigrating to '
#                                  'Canada?',
#                                  '5. What are the most requested immigration '
#                                  'programs in Canada?'],
#                    'subheading': 'Most requested'},
#                   {'content': '', 'subheading': 'Services and information'},
#                   {'content': 'Immigrate as a skilled worker\n\n',
#                    'questions': ['1. What is the process for immigrating to '
#                                  'Canada as a skilled worker?',
#                                  '2. What is Express Entry and how does it '
#                                  'work?',
#                                  '3. What are the requirements for immigrating '
#                                  'to Canada through Express Entry?',
#                                  '4. How can I increase my chances of being '
#                                  'selected for Express Entry?',
#                                  '5. Are there any specific occupations or '
#                                  'skills that are in high demand in Canada for '
#                                  'skilled workers?'],
#                    'subheading': 'Express Entry'},
#                   {'content': 'Sponsor your relatives, including your spouse, '
#                               'partner, children, parents, grandparents, and '
#                               'others to immigrate\n'
#                               '\n',
#                    'questions': ['1. Who can I sponsor to immigrate to Canada?',
#                                  '2. Can I sponsor my spouse or partner to '
#                                  'immigrate to Canada?',
#                                  '3. Can I sponsor my parents or grandparents '
#                                  'to immigrate to Canada?',
#                                  '4. Are there any other relatives I can '
#                                  'sponsor to immigrate to Canada?',
#                                  '5. What is the process for sponsoring family '
#                                  'members to immigrate to Canada?'],
#                    'subheading': 'Family sponsorship'},
#                   {'content': 'Immigrate by being nominated by a Canadian '
#                               'province or territory\n'
#                               '\n',
#                    'questions': ['1. What is the process for immigrating to '
#                                  'Canada through provincial nomination?',
#                                  '2. How does being nominated by a Canadian '
#                                  'province or territory increase your chances '
#                                  'of immigrating to Canada?',
#                                  '3. Which provinces or territories in Canada '
#                                  'offer provincial nominee programs?',
#                                  '4. What are the eligibility criteria for '
#                                  'applying for provincial nomination?',
#                                  '5. Can you apply for provincial nomination '
#                                  "if you don't have a job offer in Canada?"],
#                    'subheading': 'Provincial nominees'},
#                   {'content': 'Immigrate as a skilled worker in the province '
#                               'of Quebec\n'
#                               '\n',
#                    'questions': ['1. What is the process for immigrating to '
#                                  'Canada as a skilled worker in Quebec?',
#                                  '2. What are the requirements for being '
#                                  'selected as a skilled worker in Quebec?',
#                                  '3. How does the Quebec-selected skilled '
#                                  'worker program differ from other immigration '
#                                  'programs in Canada?',
#                                  '4. Are there any specific occupations or '
#                                  'industries that are in high demand in '
#                                  'Quebec?',
#                                  '5. What are the benefits of immigrating to '
#                                  'Quebec as a skilled worker?'],
#                    'subheading': 'Quebec-selected skilled workers'},
#                   {'content': 'Immigrate by graduating from a school or '
#                               'working in New Brunswick, Prince Edward Island, '
#                               'Nova Scotia, or Newfoundland and Labrador\n'
#                               '\n',
#                    'questions': ['1. How can I immigrate to Canada through the '
#                                  'Atlantic Immigration Program?',
#                                  '2. What are the eligibility requirements for '
#                                  'immigrating to Canada through the Atlantic '
#                                  'Immigration Program?',
#                                  '3. Can I immigrate to Canada through the '
#                                  'Atlantic Immigration Program if I have '
#                                  'graduated from a school in one of the '
#                                  'Atlantic provinces?',
#                                  '4. What are the benefits of immigrating to '
#                                  'Canada through the Atlantic Immigration '
#                                  'Program?',
#                                  '5. Are there any specific job requirements '
#                                  'or qualifications needed to immigrate to '
#                                  'Canada through the Atlantic Immigration '
#                                  'Program?'],
#                    'subheading': 'Atlantic Immigration Program'},
#                   {'content': 'Immigrate by providing care for children, the '
#                               'elderly or those with medical needs, or work as '
#                               'a live-in caregiver\n'
#                               '\n',
#                    'questions': ['1. What are the different ways to immigrate '
#                                  'to Canada as a caregiver?',
#                                  '2. What types of individuals can caregivers '
#                                  'provide care for in Canada?',
#                                  '3. What is the process for becoming a '
#                                  'live-in caregiver in Canada?',
#                                  '4. What are the requirements for immigrating '
#                                  'to Canada as a caregiver?',
#                                  '5. What are the benefits of immigrating to '
#                                  'Canada as a caregiver?'],
#                    'subheading': 'Caregivers'},
#                   {'content': 'Immigrate by starting a business and creating '
#                               'jobs\n'
#                               '\n',
#                    'questions': ['1. What is the main pathway to immigrate to '
#                                  'Canada through entrepreneurship?',
#                                  '2. How does the Start-up Visa program in '
#                                  'Canada work?',
#                                  '3. What are the requirements for obtaining a '
#                                  'Start-up Visa in Canada?',
#                                  '4. How does starting a business and creating '
#                                  'jobs contribute to the immigration process '
#                                  'in Canada?',
#                                  '5. What are the benefits of immigrating to '
#                                  'Canada through the Start-up Visa program?'],
#                    'subheading': 'Start-up Visa'},
#                   {'content': 'Immigrate as a self-employed person in cultural '
#                               'or athletic activities\n'
#                               '\n',
#                    'questions': ['1. What is the specific immigration category '
#                                  'for self-employed individuals in Canada?',
#                                  '2. What types of cultural or athletic '
#                                  'activities qualify for immigration under '
#                                  'this category?',
#                                  '3. What are the eligibility requirements for '
#                                  'immigrating as a self-employed person in '
#                                  'Canada?',
#                                  '4. How can one demonstrate their experience '
#                                  'and ability in cultural or athletic '
#                                  'activities?',
#                                  '5. What are the steps involved in the '
#                                  'immigration process for self-employed '
#                                  'individuals in Canada?'],
#                    'subheading': 'Self-employed'},
#                   {'content': 'Smaller Canadian communities supporting their '
#                               'local economy through immigration. Pilot opens '
#                               'to permanent resident applicants later in '
#                               '2019.\n'
#                               '\n',
#                    'questions': ['1. What is the Rural and Northern '
#                                  'Immigration Pilot in Canada?',
#                                  '2. How are smaller Canadian communities '
#                                  'benefiting from immigration?',
#                                  '3. When will the pilot open to permanent '
#                                  'resident applicants?',
#                                  '4. What is the purpose of the pilot program?',
#                                  '5. How does the pilot program support the '
#                                  'local economy in rural and northern areas of '
#                                  'Canada?'],
#                    'subheading': 'Rural and Northern Immigration Pilot'},
#                   {'content': 'Immigrate by working in specific agri-food '
#                               'industries and occupations\n'
#                               '\n',
#                    'questions': ['1. What is the Agri-Food Pilot program in '
#                                  'Canada?',
#                                  '2. How can immigrants benefit from working '
#                                  'in specific agri-food industries and '
#                                  'occupations?',
#                                  '3. What are the requirements for immigrating '
#                                  'to Canada through the Agri-Food Pilot '
#                                  'program?',
#                                  '4. What are some examples of specific '
#                                  'agri-food industries and occupations covered '
#                                  'by the program?',
#                                  '5. How can immigrants apply for the '
#                                  'Agri-Food Pilot program and start the '
#                                  'immigration process?'],
#                    'subheading': 'Agri-Food Pilot'},
#                   {'content': 'The temporary resident to permanent resident '
#                               'pathway is a limited-time pathway to permanent '
#                               'residence. It is for certain temporary '
#                               'residents who are currently working in Canada '
#                               'and their families.\n'
#                               '\n',
#                    'questions': ['1. What is the temporary resident to '
#                                  'permanent resident pathway in Canada?',
#                                  '2. Who is eligible for the temporary '
#                                  'resident to permanent resident pathway?',
#                                  '3. What is the purpose of this pathway?',
#                                  '4. How does one qualify for permanent '
#                                  'residence through this pathway?',
#                                  '5. Is this pathway available to temporary '
#                                  'residents who are not currently working in '
#                                  'Canada?'],
#                    'subheading': 'Temporary resident to permanent resident '
#                                  'pathway'},
#                   {'content': 'Two pathways to permanent residence for '
#                               'eligible Hong Kong residents who are currently '
#                               'in Canada.\n'
#                               '\n',
#                    'questions': ['1. What are the permanent residence pathways '
#                                  'available for Hong Kong residents in Canada?',
#                                  '2. How can eligible Hong Kong residents '
#                                  'apply for permanent residence in Canada?',
#                                  '3. Are there any specific requirements or '
#                                  'criteria that Hong Kong residents need to '
#                                  'meet to be eligible for permanent residence '
#                                  'in Canada?',
#                                  '4. Can Hong Kong residents who are currently '
#                                  'in Canada apply for permanent residence '
#                                  'through these pathways?',
#                                  '5. What are the benefits of obtaining '
#                                  'permanent residence in Canada for Hong Kong '
#                                  'residents?'],
#                    'subheading': 'Permanent residence pathways for Hong Kong '
#                                  'residents'},
#                   {'content': 'Immigrate through economic permanent residence '
#                               'pathways as an eligible skilled refugee\n'
#                               '\n',
#                    'questions': ['1. What is the Economic Mobility Pathways '
#                                  'Pilot in Canada?',
#                                  '2. How can eligible skilled refugees '
#                                  'immigrate to Canada?',
#                                  '3. What are the economic permanent residence '
#                                  'pathways available for skilled refugees?',
#                                  '4. What are the benefits of immigrating to '
#                                  'Canada through economic permanent residence '
#                                  'pathways?',
#                                  '5. How does the Economic Mobility Pathways '
#                                  'Pilot contribute to economic mobility for '
#                                  'skilled refugees in Canada?'],
#                    'subheading': 'Economic Mobility Pathways Pilot'},
#                   {'content': 'Immigrate as a refugee or become a sponsor\n\n',
#                    'questions': ['1. How can I immigrate to Canada as a '
#                                  'refugee?',
#                                  '2. What are the requirements for immigrating '
#                                  'to Canada as a refugee?',
#                                  '3. Can I sponsor a refugee to immigrate to '
#                                  'Canada?',
#                                  '4. What is the process for becoming a '
#                                  'sponsor for a refugee in Canada?',
#                                  '5. Are there any specific programs or '
#                                  'resources available for refugees immigrating '
#                                  'to Canada?'],
#                    'subheading': 'Refugees'},
#                   {'content': 'Live, work or study in French in a Francophone '
#                               'community outside Quebec.\n'
#                               '\n',
#                    'questions': ['1. What opportunities are available for '
#                                  'individuals who want to live, work, or study '
#                                  'in French in Canada?',
#                                  '2. Where can one find Francophone '
#                                  'communities outside of Quebec to immigrate '
#                                  'to in Canada?',
#                                  '3. What are the benefits of immigrating to a '
#                                  'Francophone community in Canada?',
#                                  '4. What are the requirements for immigrating '
#                                  'to Canada and living, working, or studying '
#                                  'in French?',
#                                  '5. How can one navigate the immigration '
#                                  'process to Canada and ensure a successful '
#                                  'transition to a Francophone community?'],
#                    'subheading': 'Francophone immigration'},
#                   {'content': 'Appeal to the Immigration and Refugee Board '
#                               'about sponsorship, removal orders and residency '
#                               'obligation requirements.\n'
#                               '\n',
#                    'questions': ['1. How can I appeal a sponsorship decision '
#                                  'in Canada?',
#                                  '2. What is the process for appealing a '
#                                  'removal order in Canada?',
#                                  '3. What are the residency obligation '
#                                  'requirements for immigrants in Canada?',
#                                  '4. How can I appeal a decision made by the '
#                                  'Immigration and Refugee Board?',
#                                  '5. What are the possible outcomes of an '
#                                  'appeal to the Immigration and Refugee '
#                                  'Board?'],
#                    'subheading': 'Appeal your immigration decision'},
#                   {'content': 'Immigration, Refugees and Citizenship Canada\n'
#                               'Immigration and Refugee Board of Canada\n'
#                               '\n',
#                    'questions': ['1. What is the role of Immigration, Refugees '
#                                  'and Citizenship Canada in the immigration '
#                                  'process to Canada?',
#                                  '2. How can the Immigration and Refugee Board '
#                                  'of Canada assist individuals seeking refuge '
#                                  'in Canada?',
#                                  '3. What are the requirements for immigrating '
#                                  'to Canada?',
#                                  '4. What services does Immigration, Refugees '
#                                  'and Citizenship Canada provide to '
#                                  'immigrants?',
#                                  '5. How does the Immigration and Refugee '
#                                  'Board of Canada make decisions regarding '
#                                  'refugee claims?'],
#                    'subheading': 'Contributors'},
#                   {'content': '', 'subheading': 'Features'},
#                   {'content': '', 'subheading': 'Page details'},
#                   {'content': '', 'subheading': 'About this site'},
#                   {'content': 'Help Centre\nContact us\n\n',
#                    'questions': ['1. What is the process for immigrating to '
#                                  'Canada?',
#                                  '2. How can I obtain Canadian citizenship?',
#                                  '3. What services does the Help Centre '
#                                  'provide for immigrants?',
#                                  '4. How can I contact the Help Centre for '
#                                  'assistance with immigration and citizenship?',
#                                  '5. Are there any specific requirements or '
#                                  'qualifications for immigrating to Canada?'],
#                    'subheading': 'Immigration and citizenship'},
#                   {'content': 'All contacts\n'
#                               'Departments and agencies\n'
#                               'About government\n'
#                               '\n',
#                    'questions': ['1. How can I immigrate to Canada?',
#                                  '2. What is the role of the Government of '
#                                  'Canada in the immigration process?',
#                                  '3. Where can I find contact information for '
#                                  'the relevant departments and agencies '
#                                  'involved in immigration?',
#                                  '4. What are the different departments and '
#                                  'agencies involved in the immigration '
#                                  'process?',
#                                  '5. What information can I find about the '
#                                  "Canadian government's policies and "
#                                  'initiatives regarding immigration?'],
#                    'subheading': 'Government of Canada'},
#                   {'content': 'Jobs\n'
#                               'Immigration and citizenship\n'
#                               'Travel and tourism\n'
#                               'Business\n'
#                               'Benefits\n'
#                               'Health\n'
#                               'Taxes\n'
#                               'Environment and natural resources\n'
#                               'National security and defence\n'
#                               'Culture, history and sport\n'
#                               'Policing, justice and emergencies\n'
#                               'Transport and infrastructure\n'
#                               'Canada and the world\n'
#                               'Money and finance\n'
#                               'Science and innovation\n'
#                               'Indigenous peoples\n'
#                               'Veterans and military\n'
#                               'Youth\n'
#                               '\n',
#                    'questions': ['1. What are the job opportunities available '
#                                  'for immigrants in Canada?',
#                                  '2. What are the benefits of immigrating to '
#                                  'Canada?',
#                                  '3. How does the immigration and citizenship '
#                                  'process work in Canada?',
#                                  '4. What are the healthcare and health '
#                                  'benefits for immigrants in Canada?',
#                                  '5. What are the tax implications for '
#                                  'immigrants in Canada?'],
#                    'subheading': 'Themes and topics'},
#                   {'content': 'Social media\n'
#                               'Mobile applications\n'
#                               'About Canada.ca\n'
#                               'Terms and conditions\n'
#                               'Privacy\n'
#                               '\n',
#                    'questions': ['1. What resources are available for '
#                                  'immigrants looking to move to Canada?',
#                                  '2. How can social media platforms assist in '
#                                  'the immigration process to Canada?',
#                                  '3. Are there any mobile applications '
#                                  'specifically designed to help immigrants '
#                                  'navigate the immigration process in Canada?',
#                                  '4. What information can be found on the '
#                                  'Canada.ca website regarding immigration to '
#                                  'Canada?',
#                                  '5. What are the terms and conditions and '
#                                  'privacy policies that individuals should be '
#                                  'aware of when using government resources for '
#                                  'immigration to Canada?'],
#                    'subheading': 'Government of Canada Corporate'}],
#   'title': 'Immigrate to Canada'},
#  {'source': 'https://www.canada.ca/en/immigration-refugees-citizenship/services/immigrate-canada/express-entry/documents.html',
#   'subheadings': [{'content': 'You need certain documents at different stages '
#                               'of the Express Entry application process.',
#                    'questions': ['1. What documents are required for the '
#                                  'Express Entry application process?',
#                                  '2. How many stages are there in the Express '
#                                  'Entry application process?',
#                                  '3. Are the required documents the same for '
#                                  'all stages of the Express Entry application?',
#                                  '4. Can you provide a list of specific '
#                                  'documents needed for each stage of the '
#                                  'Express Entry application?',
#                                  '5. Are there any additional documents that '
#                                  "may be required depending on the applicant's "
#                                  'specific circumstances?'],
#                    'subheading': 'Documents for Express Entry'},
#                   {'content': 'You don’t need to upload documents to submit a '
#                               'profile, but you may need information from some '
#                               'or all of these documents:\n'
#                               'a passport or travel document\r\n'
#                               '\t\t\n'
#                               'Venezuelan passport holders: You may need to '
#                               'complete extra steps when you create a profile '
#                               'or fill out your application.\n'
#                               '\n'
#                               '\n'
#                               'language test results\n'
#                               'proof of Canadian education or an educational '
#                               'credential assessment report for immigration '
#                               'purposes if\r\n'
#                               '\t\t\n'
#                               'you’re applying through the Federal Skilled '
#                               'Workers Program, or\n'
#                               'you want to get points for the education you '
#                               'got outside Canada\n'
#                               '\n'
#                               '\n'
#                               'provincial nomination (if you have one)\n'
#                               'written job offer from an employer in Canada '
#                               '(if you have one), proof of work experience, '
#                               'certificate of qualification in a trade '
#                               'occupation issued by a Canadian province or '
#                               'territory (if you have one)\n'
#                               'proof of funds\n',
#                    'questions': ['1. Do I need to upload any documents to '
#                                  'submit a profile for Express Entry?',
#                                  '2. What documents do Venezuelan passport '
#                                  'holders need to provide when creating a '
#                                  'profile or filling out an application?',
#                                  '3. When do I need to provide language test '
#                                  'results for Express Entry?',
#                                  '4. What documents do I need to provide for '
#                                  'Canadian education or educational credential '
#                                  'assessment for immigration purposes?',
#                                  '5. What documents are required for proof of '
#                                  'work experience and qualification in a trade '
#                                  'occupation for Express Entry?'],
#                    'subheading': 'Documents for your profile'},
#                   {'content': 'If we invite you to apply, you’ll need to '
#                               'upload copies of the documents you used for '
#                               'your profile (see list above). Most applicants '
#                               'will also need to upload the following:\n'
#                               'police certificates\n'
#                               'medical exams\n'
#                               'proof of funds\n'
#                               'birth certificate\r\n'
#                               '\t\t\n'
#                               'required if you’re declaring dependent '
#                               'children\n'
#                               '\n'
#                               '\n'
#                               'use of a representative form (PDF, 137\xa0KB)\n'
#                               '\n'
#                               'required if you’ve hired a representative\n'
#                               '\n'
#                               '\n'
#                               'common-law union form (PDF, 2.22\xa0MB)\n'
#                               '\n'
#                               'required if you’ve declared your marital status '
#                               'as “common-law”\n'
#                               '\n'
#                               '\n'
#                               'marriage certificate\r\n'
#                               '\t\t\n'
#                               'required if you’ve declared your marital status '
#                               'as “married”\n'
#                               '\n'
#                               '\n'
#                               'divorce certificate and legal separation '
#                               'agreement\r\n'
#                               '\t\t\n'
#                               'required if you’ve declared your marital status '
#                               'as “divorced”\n'
#                               '\n'
#                               '\n'
#                               'death certificate\r\n'
#                               '\t\t\n'
#                               'required if you’ve declared your marital status '
#                               'as “widowed”\n'
#                               '\n'
#                               '\n'
#                               'adoption certificate\r\n'
#                               '\t\t\n'
#                               'required when a dependent child is listed as '
#                               '“adopted”\n'
#                               '\n'
#                               '\n',
#                    'questions': ['1. What documents do I need to upload if I '
#                                  'am invited to apply for Express Entry?',
#                                  '2. What additional documents do most '
#                                  'applicants need to upload?',
#                                  '3. When is a birth certificate required for '
#                                  'the application?',
#                                  '4. What form should be uploaded if a '
#                                  'representative is hired?',
#                                  '5. What documents are required for different '
#                                  'marital statuses?'],
#                    'subheading': 'Documents for your application for permanent '
#                                  'residence'},
#                   {'content': 'You only need to submit these if we included '
#                               'them in your personalized document checklist. '
#                               'Your application may not be refused or rejected '
#                               'if you don’t submit these documents. They’re '
#                               'only used to check if you meet the requirements '
#                               'of the program you’re applying for.\n'
#                               'proof of relationship to a relative in Canada\n'
#                               'digital photos to confirm your identity\n'
#                               'other name to confirm aliases\n'
#                               'authority to release personal information to a '
#                               'designated individual form (PDF, 1.74\xa0MB)\n'
#                               'any other documents that you feel are relevant '
#                               'to your application\n',
#                    'questions': ['1. What documents are required for Express '
#                                  'Entry?',
#                                  '2. Are these additional documents necessary '
#                                  'for the application?',
#                                  '3. Will my application be rejected if I '
#                                  "don't submit these documents?",
#                                  '4. What is the purpose of submitting proof '
#                                  'of relationship to a relative in Canada?',
#                                  '5. Can I include any other relevant '
#                                  'documents in my application?'],
#                    'subheading': 'Other documents'},
#                   {'content': '\n'
#                               'Follow these steps, if the printed expiry date '
#                               'has passed, and you’re creating a profile or '
#                               'submitting an application under Express Entry:\n'
#                               '\n'
#                               'Add 5 years to the printed expiry date shown on '
# ...
#                               'allows multiple entries for up to 10 years.\n',
#                    'questions': ['1. Is the parent and grandparent super visa '
#                                  'a multi-entry visa?',
#                                  '2. How long is the super visa valid for?',
#                                  '3. Can the super visa be used for multiple '
#                                  'entries within the 10-year period?',
#                                  '4. What is the purpose of the parent and '
#                                  'grandparent super visa?',
#                                  '5. Are there any restrictions or limitations '
#                                  'on the number of entries allowed with the '
#                                  'super visa?'],
#                    'subheading': 'Is the parent and grandparent super visa a '
#                                  'multi-entry visa?'},
#                   {'content': '\n'
#                               '\n'
#                               'No. Simply apply for a visitor visa online or '
#                               'on paper.\n'
#                               'For paper applications, check the\xa0document '
#                               'checklist\xa0for full details of what you need '
#                               'to submit with your application.\n'
#                               'Please note:\n'
#                               '\n'
#                               'Visa application centres are not involved in '
#                               'the visa decision-making process and can’t '
#                               'provide advice to applicants.\n'
#                               'All decisions on applications are made by visa '
#                               'officers at Immigration, Refugees and '
#                               'Citizenship Canada visa offices.\n'
#                               'Applications that meet the criteria will also '
#                               'be processed faster.\n'
#                               '\n',
#                    'questions': ['1. Is there a separate application form for '
#                                  'CAN+?',
#                                  '2. How can I apply for a visitor visa?',
#                                  '3. What documents do I need to submit with '
#                                  'my paper application?',
#                                  '4. Can visa application centres provide '
#                                  'advice to applicants?',
#                                  '5. Will applications that meet the criteria '
#                                  'be processed faster?'],
#                    'subheading': 'Is there a different application form for '
#                                  'CAN+?'},
#                   {'content': '\n'
#                               '\n'
#                               'Yes. The file size limit varies depending on '
#                               'which online application account you use.\n'
#                               '\n'
#                               'If your file is too big,\xa0there are ways to  '
#                               'reduce its size.\n'
#                               '\n'
#                               '\n'
#                               '\n'
#                               '\n'
#                               '\n'
#                               'Online account type\n'
#                               'File size limit (per file)\n'
#                               '\n'
#                               '\n'
#                               '\n'
#                               '\n'
#                               'IRCC secure account\n'
#                               '4 MB\n'
#                               '\n'
#                               '\n'
#                               'IRCC Portal\n'
#                               '2 MB\n'
#                               '\n'
#                               '\n'
#                               'Online citizenship application\n'
#                               '2 MB\n'
#                               '\n'
#                               '\n'
#                               'Asylum portal\n'
#                               '4 MB\n'
#                               '\n'
#                               '\n'
#                               'Permanent Residence Portal\n'
#                               '4 MB\n'
#                               '\n'
#                               '\n'
#                               '\n'
#                               '\n',
#                    'questions': ['1. What is the file size limit for documents '
#                                  'uploaded to an IRCC secure account?',
#                                  '2. What is the file size limit for documents '
#                                  'uploaded to the IRCC Portal?',
#                                  '3. What is the file size limit for documents '
#                                  'uploaded to an online citizenship '
#                                  'application?',
#                                  '4. What is the file size limit for documents '
#                                  'uploaded to the Asylum portal?',
#                                  '5. What is the file size limit for documents '
#                                  'uploaded to the Permanent Residence Portal?'],
#                    'subheading': 'Is there a file size limit for documents I '
#                                  'upload to my account?'},
#                   {'content': '\n'
#                               '\n'
#                               'Yes. We only process up to 5,500 applications '
#                               'each year under the caregiver pilots: \n'
#                               '\n'
#                               '2,750 applications for the Home Child Care '
#                               'Provider Pilot\n'
#                               '2,750 applications for the Home Support Worker '
#                               'Pilot\n'
#                               '\n'
#                               'If your application is incomplete or we receive '
#                               'it after the limit has been reached, we return '
#                               'it to you along with your processing fees.\n'
#                               '\n'
#                               'The pilot caps reset on January 1, 2023\n'
#                               'As of January 1, 2023, you can apply under the '
#                               '2023 caps for the Home Child Care Provider '
#                               'Pilot and the Home Support Worker Pilot.\n'
#                               'There are changes for the 2023 application '
#                               'process\n'
#                               'Read all the changes to these pilots before you '
#                               'apply. Make sure you follow our updated '
#                               'instructions.\n'
#                               '2023 application caps\n'
#                               'Before you apply, make sure you check the '
#                               'latest updates about the cap for the pilot and '
#                               'category you want to apply to.\n'
#                               '\n',
#                    'questions': ['1. How many caregiver applications does the '
#                                  'IRCC accept each year under the pilots?',
#                                  '2. What is the application limit for the '
#                                  'Home Child Care Provider Pilot?',
#                                  '3. What is the application limit for the '
#                                  'Home Support Worker Pilot?',
#                                  '4. What happens if an application is '
#                                  'incomplete or received after the limit has '
#                                  'been reached?',
#                                  '5. When do the pilot caps reset and when can '
#                                  'applicants apply under the 2023 caps?'],
#                    'subheading': 'Is there a limit on the number of caregiver '
#                                  'applications you accept under the pilots?'},
#                   {'content': '\n'
#                               '\n'
#                               'The maximum loan amount that can be issued per '
#                               'family is $10,000 CAD. A family includes the '
#                               'principal applicant and:\n'
#                               '\n'
#                               'his/her spouse or common-law partner \n'
#                               'dependent children \n'
#                               'dependent children of the applicant’s spouse or '
#                               'common-law partner\n'
#                               '\n',
#                    'questions': ['1. What is the maximum loan amount that can '
#                                  'be issued per family?',
#                                  '2. Who is considered part of a family for '
#                                  'the purpose of determining the maximum loan '
#                                  'amount?',
#                                  '3. Is there a limit on the loan amount for '
#                                  'each individual within a family?',
#                                  '4. Can the loan amount be increased if there '
#                                  'are additional dependents in the family?',
#                                  '5. Is the maximum loan amount different for '
#                                  'different types of applicants, such as '
#                                  'principal applicants and their spouses?'],
#                    'subheading': 'Is there a maximum loan amount?'},
#                   {'content': '\n'
#                               '\n'
#                               'There is no regulated minimum net worth '
#                               'requirement. However, you will have to satisfy '
#                               'a visa officer that you have enough money to:\n'
#                               '\n'
#                               'settle in Canada with your dependants and\n'
#                               'finance the work on which your selection was '
#                               'based.\n'
#                               '\n'
#                               'Find out more about the funds you need.\n',
#                    'questions': ['1. Is there a minimum net worth requirement '
#                                  'for the self-employed program?',
#                                  '2. What factors do I need to consider '
#                                  'regarding my finances when applying for the '
#                                  'self-employed program?',
#                                  '3. Do I need to prove that I have enough '
#                                  'money to support myself and my dependents in '
#                                  'Canada?',
#                                  '4. What is the purpose of the net worth '
#                                  'requirement for the self-employed program?',
#                                  '5. Where can I find more information about '
#                                  'the funds I need for the self-employed '
#                                  'program?'],
#                    'subheading': 'Is there a net worth requirement for the '
#                                  'self-employed program?'},
#                   {'content': '\n'
#                               '\n'
#                               'Yes, your clients can confirm their status by '
#                               'using the eTA check status tool.\n'
#                               'The Government of Canada will also send email '
#                               'updates to the email address provided on the '
#                               'eTA application form. These emails will:\n'
#                               '\n'
#                               'acknowledge receipt of their application,\n'
#                               'provide an update and instructions if '
#                               'additional information is needed,\n'
#                               'confirm the final decision about their eTA '
#                               'application.\n'
#                               '\n',
#                    'questions': ['1. How can clients confirm the status of '
#                                  'their eTA?',
#                                  '2. Will the Government of Canada send email '
#                                  'updates regarding the eTA application?',
#                                  '3. What information will the email updates '
#                                  'provide?',
#                                  '4. What are the purposes of the emails sent '
#                                  'by the Government of Canada?',
#                                  '5. How will clients be notified about the '
#                                  'final decision on their eTA application?'],
#                    'subheading': 'Is there a way for clients to confirm the '
#                                  'status of their eTA?'},
#                   {'content': '\n'
#                               '\n'
#                               'No. To get a letter of support, you need to '
#                               'convince a designated organization that your '
#                               'business idea is worth supporting. To do that, '
#                               'contact the designated organization you think '
#                               'may be interested in your start-up business and '
#                               'find out how you can pitch your idea.\n'
#                               'Each designated organization has its own '
#                               'requirements. For example, you may be asked to '
#                               'present your business concept in person or '
#                               'submit a detailed business plan.\n',
#                    'questions': ['1. Is there an application form to obtain a '
#                                  'letter of support from a designated '
#                                  'organization?',
#                                  '2. How can I convince a designated '
#                                  'organization to provide a letter of support '
#                                  'for my business idea?',
#                                  '3. What should I do to pitch my start-up '
#                                  'business idea to a designated organization?',
#                                  '4. Are there specific requirements for each '
#                                  'designated organization when seeking a '
#                                  'letter of support?',
#                                  '5. What are some examples of requirements '
#                                  'that a designated organization may have when '
#                                  'considering a letter of support?'],
#                    'subheading': 'Is there an application form to get a letter '
#                                  'of support from a designated organization?'},
#                   {'content': '\n'
#                               '\n'
#                               'It depends on the immigration status of your '
#                               'family members. If your family members are '
#                               'temporary residents (visitors), they have to '
#                               'apply for a work permit to be able to work.\n'
#                               'Your family members can apply for a work permit '
#                               'from within Canada if they are in 1 of the '
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
"""Loader that loads data from JSON."""

from pathlib import Path
from typing import Callable, Dict, List, Optional, Union

from langchain.docstore.document import Document
from langchain.document_loaders.base import BaseLoader


class JSONLoader(BaseLoader):
    def __init__(
        self,
        file_path: Union[str, Path],
        content_key: Optional[str] = None,
        ):
        self.file_path = Path(file_path).resolve()
        self._content_key = content_key
        
    def load(self) -> List[Document]:
        """Load and return documents from the JSON file."""

        docs=[]
        # Load JSON file
        with open(self.file_path) as file:
            data = json.load(file)

        # Iterate through 'pages'
        for c in data:
            parenturl = c['source']
            pagetitle = c['title']
            snippets = c['subheadings']
            metadata={"title":pagetitle, "source": parenturl}
            
            print(pagetitle)
            # # Process snippets for each page
            for snippet in snippets:
                content = snippet['content']
                subheading = snippet['subheading']
                docs.append(Document(page_content=content, metadata=metadata))
        return docs

# %%
# load the data using JSONLoader and printing the page tiles
loader = JSONLoader(file_path=file_path)
data = loader.load()
# Out:
# Express Entry: Check your application status
# Immigrate to Canada
# Documents for Express Entry
# Express Entry: Check your application status
# Welcome to Canada: Finding a place to live
# Housing and accommodations in Canada
# How the Provincial Nominee Program (PNP) works
# Immigrate as a provincial nominee
# Immigrate as a provincial nominee (non-Express Entry process)
# Immigrate as a provincial nominee through Express Entry
# IRCC Help Centre
# Study permit: Get the right documents
# Study permit: How to apply
# Study permit: Prepare for arrival
# The Proof of Relationship to a Relative in Canada
# Open work permit: Applying as a sponsored spouse or common-law partner in Canada
# Canada visa interview questions

# %%
pprint(data[:5])
# Out:
# [Document(page_content='1. Fill out the online form\n2. Scan and upload the documents\n3. Pay your fees\n4. Submit your complete application\n5. After you apply\nCheck your application status', metadata={'title': '\nExpress Entry: Check your application status', 'source': 'https://www.canada.ca/en/immigration-refugees-citizenship/services/immigrate-canada/express-entry/apply-permanent-residence/check-your-status.html'}),
#  Document(page_content='Starting February 8, 2023, use the application status tracker(opens in a new tab)\xa0 to get the most up-to-date and detailed information about the status of your application.\nYou have 60 days after you’ve been invited to apply to submit your application for permanent residence.\nOnce you have submitted your application, you can check its status in your account.\nGo to “View the applications you submitted”\nClick “Application status and messages”\nOn the “Application status and messages” page, you’re able to see\nthe overall status of your application\nthe current status of each application step\nmessages with additional steps to take, if required\nIf you need to make updates to your account, we’ll send you an email. Make sure you complete the requested updates as soon as possible, or the processing of your application could be delayed.', metadata={'title': '\nExpress Entry: Check your application status', 'source': 'https://www.canada.ca/en/immigration-refugees-citizenship/services/immigrate-canada/express-entry/apply-permanent-residence/check-your-status.html'}),
#  Document(page_content='We process most Express Entry applications within 6 months or less of getting your complete application.', metadata={'title': '\nExpress Entry: Check your application status', 'source': 'https://www.canada.ca/en/immigration-refugees-citizenship/services/immigrate-canada/express-entry/apply-permanent-residence/check-your-status.html'}),
#  Document(page_content='\n Varies by program\n\nYou may need to give your biometrics with your application. This processing time includes the time you need to give your biometrics.', metadata={'title': '\nExpress Entry: Check your application status', 'source': 'https://www.canada.ca/en/immigration-refugees-citizenship/services/immigrate-canada/express-entry/apply-permanent-residence/check-your-status.html'}),
#  Document(page_content='Processing times will vary based on:\nthe type of application submitted\nif the application is complete\nhow quickly we expect to process applications we’ve already received\nhow easily we can verify your information\nhow long you take to respond to any requests or concerns\nother factors\nMore people want to immigrate to Canada than we can bring in each year. Applications received after we meet our yearly limit may have to wait longer to be processed.\nLearn how processing times are calculated.', metadata={'title': '\nExpress Entry: Check your application status', 'source': 'https://www.canada.ca/en/immigration-refugees-citizenship/services/immigrate-canada/express-entry/apply-permanent-residence/check-your-status.html'})]

# %%
# split based on characters
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 700,
    chunk_overlap = 150
)

# %%
# splittng the document to chunks

splits = text_splitter.split_documents(data)

# %%
# Sanity check
len(data), len(splits)
# Out:
# (3674, 5896)

# %% [markdown]
# # Vector Database - Pinecone

# %% [markdown]
# Pinecone is a vector database to store the embeddings. It has many advantages like storing querrying embeddings quickly and at scale.
# https://docs.pinecone.io/docs/overview

# %%
from tqdm.autonotebook import tqdm
import pinecone

# %%
# api key from the pinecone account - free tier allows 1 index
# Before creating embeddings, index should be created in Pinecone 
# Since "all-MiniLM-L6-v2" model is used for embedding, index should be created with dimension 384
pinecone.init(api_key=pinecone_api_key, 
              environment="gcp-starter")

# %% [markdown]
# ## Embeddings

# %%
# Embeddings extracted from pretrained model in hugging face

from langchain.embeddings import HuggingFaceEmbeddings, SentenceTransformerEmbeddings

embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
embeddings
# Out:
# HuggingFaceEmbeddings(client=SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#   (2): Normalize()
# ), model_name='all-MiniLM-L6-v2', cache_folder=None, model_kwargs={}, encode_kwargs={}, multi_process=False)

# %%
index_name = "chatbot"

# %%
from langchain.vectorstores import Pinecone
# run below line only if you want to add embedding to the vector database(in this case pinecone)

# vector_store = Pinecone.from_texts([split.page_content for split in splits], embeddings, index_name=index_name)

# %%
# load embeddings from existing index in vector database
vector_store = Pinecone.from_existing_index(index_name=index_name, embedding = embeddings)

# %% [markdown]
# # Retrieval Augmented Generation (RAG) flow

# %%
# initializing openai chat model
from langchain.chat_models import ChatOpenAI
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)
llm.predict("Hello world!")
# Out:
# 'Hello! How can I assist you today?'

# %%
# Build prompt
from langchain.prompts import PromptTemplate
template = """You are a virtual assistant to help users about questions on Canadian immigration process. \
      Use the following pieces of context to answer the question at the end.\
      If you don't know the answer, just say that you don't know, don't try to make up an answer.\
      Keep the answer as concise as possible. \
      Add bullet points in the reply while explaining a process or steps \
         
{context}
Question: {question}
Helpful Answer:"""
QA_CHAIN_PROMPT = PromptTemplate(input_variables=["context", "question"],template=template,)

# %%
query_1 = "What is express entry"
query_2 = "I'm a student. Can I apply under that category?"

# %%
# Run chain
from langchain.chains import RetrievalQA
# question_1 = "I got PR yesterday. Can I apply sponsorship for my wife and kid?"
qa_chain = RetrievalQA.from_chain_type(llm,
                                       retriever=vector_store.as_retriever(),
                                       return_source_documents=True,
                                       chain_type_kwargs={"prompt": QA_CHAIN_PROMPT})

# %%
result_1 = qa_chain({"query": query_1})
print(result_1["result"])
# Out:
# Express Entry is an online system used by the Canadian government to manage applications for permanent residence from skilled workers. It is a competitive immigration program that allows individuals to submit their profiles and be considered for various economic immigration programs, such as the Federal Skilled Worker Program, the Federal Skilled Trades Program, and the Canadian Experience Class. The Express Entry system uses a points-based system called the Comprehensive Ranking System (CRS) to rank candidates based on factors such as age, education, work experience, language proficiency, and adaptability. Candidates with the highest CRS scores are invited to apply for permanent residence through regular draws conducted by the government.

# %%
result_2 = qa_chain({"query": query_2})
print(result_2["result"])
# Out:
# Yes, as a student, you may be eligible to apply for Canadian immigration under certain categories.

# %% [markdown]
# # Simple chatbot

# %%
# while True:
#     prompt = input(prompt="User: ")
#     # print()
#     result = qa({"question": prompt})
#     print("Bot: " + result["answer"])
#     # print()

# %% [markdown]
# # Adding Memory

# %%
from langchain.memory import ConversationBufferWindowMemory,ConversationBufferMemory 
from langchain.chains import ConversationChain
# memory = ConversationBufferWindowMemory(memory_key="chat_history", verbose = True)

# %%
from langchain.prompts.prompt import PromptTemplate

custom_template = """
you are a virtual assistant to help users about questions on Canadian immigration process. \
Use the following pieces of context to answer the question at the end.\
If you don't know the answer, just say that you don't know, don't try to make up an answer.\
Keep the answer as concise as possible. \
Given the following conversation and a follow up question, \
rephrase the follow up question to be a standalone question, in its original language\
Chat History:
{chat_history}
Follow Up Input: {question}
Standalone question:"""
CUSTOM_QUESTION_PROMPT = PromptTemplate.from_template(template = custom_template,)

# %%
CUSTOM_QUESTION_PROMPT = PromptTemplate.from_template(custom_template)

# %%
from langchain.chains import ConversationalRetrievalChain
# memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)
memory = ConversationBufferWindowMemory(k = 2, memory_key="chat_history",return_messages=True, verbose = True)
qa = ConversationalRetrievalChain.from_llm(
    llm,
    vector_store.as_retriever(),
    condense_question_prompt=CUSTOM_QUESTION_PROMPT,
    memory=memory
)

# %%
result = qa({"question": "What are the documents needed to apply student visa", })

# %%
print(result['answer'])
# Out:
# To apply for a student visa, you will typically need the following documents:
#
# 1. Valid passport: You will need a valid passport that does not expire during your intended stay in the country.
#
# 2. Letter of acceptance: You will need a copy of the letter of acceptance from the educational institution where you have been accepted to study.
#
# 3. Proof of financial support: You may need to provide evidence that you have enough funds to cover your tuition fees, living expenses, and other costs during your studies.
#
# 4. Proof of ties to your home country: You may need to demonstrate that you have strong ties to your home country, such as family, property, or employment, to show that you have reasons to return after completing your studies.
#
# 5. Medical examination: Some countries may require you to undergo a medical examination to ensure that you are in good health.
#
# 6. Biometrics: Depending on your citizenship, you may need to provide biometric information, such as fingerprints and a photo.
#
# 7. Visa application form: You will need to complete and submit the visa application form provided by the embassy or consulate of the country where you plan to study.
#
# It's important to note that the specific requirements may vary depending on the country you are applying to and your individual circumstances. It is recommended to check the official website of the embassy or consulate for the most up-to-date and accurate information.

# %%
# query = "What is express entry"
result = qa({"question": query_1})

# %%
print(result['answer'])
# Out:
# Express Entry is an online system used by the Government of Canada to manage applications for permanent residence from skilled workers. It is a competitive immigration program that allows individuals to submit their profiles and be considered for immigration to Canada based on factors such as age, education, work experience, language proficiency, and other criteria. The Express Entry system is used to select candidates for three main economic immigration programs: the Federal Skilled Worker Program, the Federal Skilled Trades Program, and the Canadian Experience Class.

# %%
# query = "I'm a student. Can I apply under that category?"
result = qa({"question": query_2})

# %%
print(result['answer'])
# Out:
# Yes, students can apply under the Express Entry category if they meet the requirements of one of the three federal programs covered by Express Entry. However, it is important to note that having a nomination from a province or territory can also be beneficial for students applying through Express Entry.

# %%
result
# Out:
# {'question': "I'm a student. Can I apply under that category?",
#  'chat_history': [HumanMessage(content='What is express entry', additional_kwargs={}, example=False),
#   AIMessage(content='Express Entry is an online system used by the Government of Canada to manage applications for permanent residence from skilled workers. It is a competitive immigration program that allows individuals to submit their profiles and be considered for immigration to Canada based on factors such as age, education, work experience, language proficiency, and other criteria. The Express Entry system is used to select candidates for three main economic immigration programs: the Federal Skilled Worker Program, the Federal Skilled Trades Program, and the Canadian Experience Class.', additional_kwargs={}, example=False)],
#  'answer': 'Yes, students can apply under the Express Entry category if they meet the requirements of one of the three federal programs covered by Express Entry. However, it is important to note that having a nomination from a province or territory can also be beneficial for students applying through Express Entry.'}

# %%
query_3 = "Thanks for the answer"
result = qa({"question": query_3})

# %%
print(result['answer'])
# Out:
# The minimum requirements for students to apply under the Express Entry category include:
#
# 1. Meeting the minimum requirements for one or more Express Entry programs.
# 2. Having work experience that meets the requirements of the Federal Skilled Worker Program, which includes being paid by wages or commissions, having continuous employment with no gaps, and meeting all other program requirements.
# 3. Taking a language test to demonstrate proficiency in listening, speaking, reading, and writing. The test results must be included in the Express Entry profile.
# 4. Meeting the eligibility criteria of the specific programs, such as the Federal Skilled Worker Program, Canadian Experience Class, or Federal Skilled Trades Program.

# %%
result
# Out:
# {'question': 'Thanks for the answer',
#  'chat_history': [HumanMessage(content="I'm a student. Can I apply under that category?", additional_kwargs={}, example=False),
#   AIMessage(content='Yes, students can apply under the Express Entry category if they meet the requirements of one of the three federal programs covered by Express Entry. However, it is important to note that having a nomination from a province or territory can also be beneficial for students applying through Express Entry.', additional_kwargs={}, example=False),
#   HumanMessage(content='Thanks for the answer', additional_kwargs={}, example=False),
#   AIMessage(content='To apply under the Express Entry category as a student, you must meet the minimum requirements for one or more Express Entry programs. Specifically, for the Federal Skilled Worker Program, student work experience gained while studying in Canada or abroad can count towards the minimum requirements if the work was paid by wages or commissions, was continuous with no gaps in employment, and meets all other requirements of the program. Additionally, if you have a nomination from a province or territory, you can apply through Express Entry as a provincial nominee. If you started the nomination process before January 1, 2015, you should contact the province or territory for further guidance.', additional_kwargs={}, example=False)],
#  'answer': 'The minimum requirements for students to apply under the Express Entry category include:\n\n1. Meeting the minimum requirements for one or more Express Entry programs.\n2. Having work experience that meets the requirements of the Federal Skilled Worker Program, which includes being paid by wages or commissions, having continuous employment with no gaps, and meeting all other program requirements.\n3. Taking a language test to demonstrate proficiency in listening, speaking, reading, and writing. The test results must be included in the Express Entry profile.\n4. Meeting the eligibility criteria of the specific programs, such as the Federal Skilled Worker Program, Canadian Experience Class, or Federal Skilled Trades Program.'}

# %%
query_4 = "Can you provide the link for the application process"
result = qa({"question": query_3})

# %%
print(result['answer'])
# Out:
# The minimum requirements for students to apply under the Express Entry category include:
#
# 1. Meeting the minimum requirements for one or more Express Entry programs.
# 2. Having work experience that meets the requirements of the Federal Skilled Worker Program, which includes being paid by wages or commissions, having continuous employment with no gaps, and meeting all other program requirements.
# 3. Taking a language test to demonstrate proficiency in listening, speaking, reading, and writing. The test results must be included in the Express Entry profile.
# 4. Meeting the specific eligibility criteria of the program(s) you are applying for, such as the Federal Skilled Worker Program, Canadian Experience Class, or Federal Skilled Trades Program.

# %%
result = qa({"question": question_1})

# %%
print(result['answer'])
# Out:
# Yes, if your spouse and dependent child are eligible to be sponsored and qualify for the sponsorship program, you can apply to sponsor them. There is no special process for sponsoring family members, so you would just apply using the normal process to sponsor your spouse and child.

# %%
result = qa({"question": question_2})
print(result['answer'])
# Out:
# The process for sponsoring your spouse and child is the same as the normal sponsorship process. You can apply to sponsor them using the regular sponsorship application.

# %%
question = " Can you explain the sponsorship process?"
qa({"question": question})
# Out:
# {'question': ' Can you explain the sponsorship process?',
#  'chat_history': [HumanMessage(content='I got PR yesterday. Can I apply sponsorship for my wife and kid?', additional_kwargs={}, example=False),
#   AIMessage(content='Yes, if your spouse and dependent child are eligible to be sponsored and qualify for the sponsorship program, you can apply to sponsor them. There is no special process for sponsoring family members, so you would just apply using the normal process to sponsor your spouse and child.', additional_kwargs={}, example=False),
#   HumanMessage(content='How should I apply for that?', additional_kwargs={}, example=False),
#   AIMessage(content='The process for sponsoring your spouse and child is the same as the normal sponsorship process. You can apply to sponsor them using the regular sponsorship application.', additional_kwargs={}, example=False)],
#  'answer': 'The process for sponsoring your spouse and child is the same as the normal process for sponsorship. You can apply to sponsor them using the regular sponsorship application.'}

# %%
result = qa({"question": question})
# Out:
# "To sponsor your spouse and child, you will need to go through the sponsorship process. Here is a detailed explanation of the steps involved:\n\n1. Determine your eligibility: Before starting the process, make sure you meet the eligibility requirements to sponsor your spouse and child. This includes being a Canadian citizen or permanent resident, being at least 18 years old, and meeting certain financial requirements.\n\n2. Gather the required documents: You will need to gather various documents to support your sponsorship application. This may include proof of your relationship with your spouse (such as marriage certificate or proof of common-law relationship), proof of your Canadian citizenship or permanent residency, proof of financial support, and other supporting documents.\n\n3. Complete the application forms: You will need to fill out the appropriate application forms for sponsoring your spouse and child. This includes the sponsorship application form, the permanent residence application form for your spouse, and the application form for your child.\n\n4. Pay the fees: There are fees associated with the sponsorship process. You will need to pay the sponsorship fee, the processing fee for your spouse's permanent residence application, and the fee for your child's application.\n\n5. Submit the application: Once you have completed the application forms and gathered all the required documents, you can submit your sponsorship application package to the appropriate immigration office. Make sure to double-check that everything is filled out correctly and all necessary documents are included.\n\n6. Wait for processing: After submitting your application, you will need to wait for it to be processed. The processing times can vary, so it's important to be patient during this stage.\n\n7. Attend an interview (if required): In some cases, you and your spouse may be required to attend an interview with an immigration officer. This is to verify the authenticity of your relationship and assess your eligibility for sponsorship.\n\n8. Receive a decision: Once your application has been processed, you will receive a decision on whether your sponsorship application has been approved or not. If approved, your spouse and child will be granted permanent residence in Canada.\n\nIt's important to note that the process and requirements may vary depending on your specific situation and any changes in immigration policies. It is recommended to consult the official website of Immigration, Refugees and Citizenship Canada (IRCC) or seek professional advice for the most up-to-date and accurate information."

# %%
print(result['answer'])
# Out:
# To sponsor your spouse and child, you will need to go through the sponsorship process. Here is a detailed explanation of the steps involved:
#
# 1. Determine your eligibility: Before starting the process, make sure you meet the eligibility requirements to sponsor your spouse and child. This includes being a Canadian citizen or permanent resident, being at least 18 years old, and meeting certain financial requirements.
#
# 2. Gather the required documents: You will need to gather various documents to support your sponsorship application. This may include proof of your relationship with your spouse (such as marriage certificate or proof of common-law relationship), proof of your Canadian citizenship or permanent residency, proof of financial support, and other supporting documents.
#
# 3. Complete the application forms: You will need to fill out the appropriate application forms for sponsoring your spouse and child. This includes the sponsorship application form, the permanent residence application form for your spouse, and the application form for your child.
#
# 4. Pay the fees: There are fees associated with the sponsorship process. You will need to pay the sponsorship fee, the processing fee for your spouse's permanent residence application, and the fee for your child's application.
#
# 5. Submit the application: Once you have completed the application forms and gathered all the required documents, you can submit your sponsorship application package to the appropriate immigration office. Make sure to double-check that everything is filled out correctly and all necessary documents are included.
#
# 6. Wait for processing: After submitting your application, you will need to wait for it to be processed. The processing times can vary, so it's important to be patient during this stage.
#
# 7. Attend an interview (if required): In some cases, you and your spouse may be required to attend an interview with an immigration officer. This is to verify the authenticity of your relationship and assess your eligibility for sponsorship.
#
# 8. Receive a decision: Once your application has been processed, you will receive a decision on whether your sponsorship application has been approved or not. If approved, your spouse and child will be granted permanent residence in Canada.
#
# It's important to note that the process and requirements may vary depending on your specific situation and any changes in immigration policies. It is recommended to consult the official website of Immigration, Refugees and Citizenship Canada (IRCC) or seek professional advice for the most up-to-date and accurate information.

# %%
result
# Out:
# {'question': ' Can you explain the sponsorship process?',
#  'chat_history': [HumanMessage(content='How should I apply for that?', additional_kwargs={}, example=False),
#   AIMessage(content='The process for sponsoring your spouse and child is the same as the normal sponsorship process. You can apply to sponsor them using the regular sponsorship application.', additional_kwargs={}, example=False),
#   HumanMessage(content=' Can you explain the sponsorship process?', additional_kwargs={}, example=False),
#   AIMessage(content='The process for sponsoring your spouse and child is the same as the normal process for sponsorship. You can apply to sponsor them using the regular sponsorship application.', additional_kwargs={}, example=False)],
#  'answer': "To sponsor your spouse and child, you will need to go through the sponsorship process. Here is a detailed explanation of the steps involved:\n\n1. Determine your eligibility: Before starting the process, make sure you meet the eligibility requirements to sponsor your spouse and child. This includes being a Canadian citizen or permanent resident, being at least 18 years old, and meeting certain financial requirements.\n\n2. Gather the required documents: You will need to gather various documents to support your sponsorship application. This may include proof of your relationship with your spouse (such as marriage certificate or proof of common-law relationship), proof of your Canadian citizenship or permanent residency, proof of financial support, and other supporting documents.\n\n3. Complete the application forms: You will need to fill out the appropriate application forms for sponsoring your spouse and child. This includes the sponsorship application form, the permanent residence application form for your spouse, and the application form for your child.\n\n4. Pay the fees: There are fees associated with the sponsorship process. You will need to pay the sponsorship fee, the processing fee for your spouse's permanent residence application, and the fee for your child's application.\n\n5. Submit the application: Once you have completed the application forms and gathered all the required documents, you can submit your sponsorship application package to the appropriate immigration office. Make sure to double-check that everything is filled out correctly and all necessary documents are included.\n\n6. Wait for processing: After submitting your application, you will need to wait for it to be processed. The processing times can vary, so it's important to be patient during this stage.\n\n7. Attend an interview (if required): In some cases, you and your spouse may be required to attend an interview with an immigration officer. This is to verify the authenticity of your relationship and assess your eligibility for sponsorship.\n\n8. Receive a decision: Once your application has been processed, you will receive a decision on whether your sponsorship application has been approved or not. If approved, your spouse and child will be granted permanent residence in Canada.\n\nIt's important to note that the process and requirements may vary depending on your specific situation and any changes in immigration policies. It is recommended to consult the official website of Immigration, Refugees and Citizenship Canada (IRCC) or seek professional advice for the most up-to-date and accurate information."}

# %%
# qa({"question": query, "chat_history": chat_history})

# %% [markdown]
# # Working on memory part
